# %% [markdown]
# # Preprocessing
# #Import Data
# #Data Cleaning
# #Data integration
# #Transformasi Data
# #Missing Data

# %%
#memasukkan data, mengganti nama record, menggeser value column
import pandas as pd
from numpy import math

#memasukkan data
df = pd.read_excel ('D:\MyProject\RekomendasiBeasiswa\Data\BeasiswaBI.xlsx')

#mengganti nama record
df=df.drop([0])
df=df.rename(columns={
    'NR':'NR1',
    'Unnamed: 2':'NR2',
    'Unnamed: 3':'NR3',
    'Unnamed: 4':'NR4',
    'Unnamed: 5':'NR5',
    'Unnamed: 6':'NR6',
    'Unnamed: 7':'NR7',
    'Unnamed: 8':'NR8',
    'Unnamed: 9':'NR9',
    'Unnamed: 10':'NR10',
    'Unnamed: 11':'NR11'
},inplace=False)
header=list(df)

#Menggeser value column
for i in df.index:
    j=1
    while math.isnan(float(df.loc[i, header[j]])):
        temp=df.loc[i, header[j]]
        for k in range(0,11):
            a=j+k
            b=a+1
            df.loc[i, header[a]]=df.loc[i, header[b]]
        df.loc[i, header[11]]=temp
df
# Out:
#     Status Beasiswa BI   NR1   NR2   NR3   NR4   NR5   NR6   NR7  NR8  NR9  \
# 1                  Iya  3.19  3.45  2.93  2.95  2.62  3.13  3.37  NaN  NaN
# 2                  Iya  3.31  3.45  3.46  2.95   3.4  3.42   3.5  NaN  NaN
# 3                  Iya  3.83  3.61  3.86     4  3.82  3.94  3.83  NaN  NaN
# 4                  Iya  3.06  3.37  3.32   3.1  3.15  3.37  3.84  NaN  NaN
# 5                  Iya  3.59  3.24  3.12  3.16  3.61   3.5  3.74  NaN  NaN
# ..                 ...   ...   ...   ...   ...   ...   ...   ...  ...  ...
# 292              Tidak  2.95  2.65  3.03  3.33  3.24   2.9  3.89  NaN  NaN
# 293              Tidak  3.34  3.21  3.95  3.75  3.95  3.73     4  NaN  NaN
# 294              Tidak  2.97  3.37  3.48  3.46  3.55  3.14  3.64  NaN  NaN
# 295              Tidak   3.5  3.39  3.39  3.18  3.45   NaN   NaN  NaN  NaN
# 296              Tidak  3.58  3.53  3.37   3.3  3.77   NaN   NaN  NaN  NaN
#
#     NR10 NR11    IP  Penghasilan Orang Tua  Tanggungan Orang Tua  Tahun Masuk  \
# 1    NaN  NaN  3.35              1837300.0                   3.0       2017.0
# 2    NaN  NaN  3.42              2500000.0                   1.0       2017.0
# 3    NaN  NaN  3.72              1250000.0                   4.0       2017.0
# 4    NaN  NaN  3.26              1000000.0                   5.0       2017.0
# 5    NaN  NaN  3.40              1500000.0                   2.0       2017.0
# ..   ...  ...   ...                    ...                   ...          ...
# 292  NaN  NaN  3.00              5482100.0                   4.0       2016.0
# 293  NaN  NaN  3.59              5384634.0                   3.0       2016.0
# 294  NaN  NaN  3.29              2500000.0                   4.0       2017.0
# 295  NaN  NaN  3.42               300000.0                   2.0       2018.0
# 296  NaN  NaN  3.48              1000000.0                   4.0       2018.0
#
#      Usia
# 1    18.0
# 2    19.0
# 3    20.0
# 4    20.0
# 5    18.0
# ..    ...
# 292  19.0
# 293  19.0
# 294  20.0
# 295  20.0
# 296  18.0
#
# [296 rows x 17 columns]

# %%
#menghapus column
# df.info()
for i in range(8,12):
    del df[header[i]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296 entries, 1 to 296
# Data columns (total 13 columns):
# Status Beasiswa BI       296 non-null object
# NR1                      296 non-null object
# NR2                      296 non-null object
# NR3                      296 non-null object
# NR4                      296 non-null object
# NR5                      296 non-null object
# NR6                      225 non-null object
# NR7                      225 non-null object
# IP                       296 non-null float64
# Penghasilan Orang Tua    296 non-null float64
# Tanggungan Orang Tua     296 non-null float64
# Tahun Masuk              296 non-null float64
# Usia                     296 non-null float64
# dtypes: float64(5), object(8)
# memory usage: 42.4+ KB

# %%
#Mengisi data yang kosong
x=df.loc[:,header[0]]
df['Decision']=x
del df['Status Beasiswa BI']
df
# Out:
#       NR1   NR2   NR3   NR4   NR5   NR6   NR7    IP  Penghasilan Orang Tua  \
# 1    3.19  3.45  2.93  2.95  2.62  3.13  3.37  3.35              1837300.0
# 2    3.31  3.45  3.46  2.95   3.4  3.42   3.5  3.42              2500000.0
# 3    3.83  3.61  3.86     4  3.82  3.94  3.83  3.72              1250000.0
# 4    3.06  3.37  3.32   3.1  3.15  3.37  3.84  3.26              1000000.0
# 5    3.59  3.24  3.12  3.16  3.61   3.5  3.74  3.40              1500000.0
# ..    ...   ...   ...   ...   ...   ...   ...   ...                    ...
# 292  2.95  2.65  3.03  3.33  3.24   2.9  3.89  3.00              5482100.0
# 293  3.34  3.21  3.95  3.75  3.95  3.73     4  3.59              5384634.0
# 294  2.97  3.37  3.48  3.46  3.55  3.14  3.64  3.29              2500000.0
# 295   3.5  3.39  3.39  3.18  3.45   NaN   NaN  3.42               300000.0
# 296  3.58  3.53  3.37   3.3  3.77   NaN   NaN  3.48              1000000.0
#
#      Tanggungan Orang Tua  Tahun Masuk  Usia decision
# 1                     3.0       2017.0  18.0      Iya
# 2                     1.0       2017.0  19.0      Iya
# 3                     4.0       2017.0  20.0      Iya
# 4                     5.0       2017.0  20.0      Iya
# 5                     2.0       2017.0  18.0      Iya
# ..                    ...          ...   ...      ...
# 292                   4.0       2016.0  19.0    Tidak
# 293                   3.0       2016.0  19.0    Tidak
# 294                   4.0       2017.0  20.0    Tidak
# 295                   2.0       2018.0  20.0    Tidak
# 296                   4.0       2018.0  18.0    Tidak
#
# [296 rows x 13 columns]

# %%
from chefboost import Chefboost as chef
import pandas as pd

config = {'algorithm': 'C4.5'}
model = chef.fit(df, config = config)
# Out:
# Expected: Decision, Existing:  decision
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d5023ed70240> in <module>
#       3
#       4 config = {'algorithm': 'C4.5'}
# ----> 5 model = chef.fit(df, config = config)
#
# ~\Anaconda3\lib\site-packages\chefboost\Chefboost.py in fit(df, config, validation_df)
#      52         if target_label != 'Decision':
#      53                 print("Expected: Decision, Existing: ",target_label)
# ---> 54                 raise ValueError('Please confirm that name of the target column is "Decision" and it is put to the right in pandas data frame')
#      55
#      56         #------------------------
#
# ValueError: Please confirm that name of the target column is "Decision" and it is put to the right in pandas data frame

# %% [markdown]
# # Pemodelan

# %% [markdown]
# # Pruning

# %% [markdown]
# # Testing
