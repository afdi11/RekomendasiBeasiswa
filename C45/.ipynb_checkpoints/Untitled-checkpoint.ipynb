# %% [markdown]
# # Preprocessing
# #Import Data
# #Data Cleaning
# #Data integration
# #Transformasi Data
# #Missing Data

# %%
#memasukkan data, mengganti nama record, menggeser value column
import pandas as pd
from numpy import math

#memasukkan data
df = pd.read_excel ('D:\MyProject\RekomendasiBeasiswa\Data\BeasiswaBI.xlsx')
df
# Out:
#     Status Beasiswa BI      NR Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  NaN  2015 1     2015 2     2016 1     2016 2     2017 1
# 1                  Iya     NaN        NaN        NaN        NaN       3.19
# 2                  Iya     NaN        NaN        NaN        NaN       3.31
# 3                  Iya     NaN        NaN        NaN        NaN       3.83
# 4                  Iya     NaN        NaN        NaN        NaN       3.06
# ..                 ...     ...        ...        ...        ...        ...
# 292              Tidak     NaN        NaN       2.95       2.65       3.03
# 293              Tidak     NaN        NaN       3.34       3.21       3.95
# 294              Tidak     NaN        NaN        NaN        NaN       2.97
# 295              Tidak     NaN        NaN        NaN        NaN        NaN
# 296              Tidak     NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11    IP  \
# 0       2017 2     2018 1     2018 2     2019 1      2019 2      2020 1   NaN
# 1         3.45       2.93       2.95       2.62        3.13        3.37  3.35
# 2         3.45       3.46       2.95        3.4        3.42         3.5  3.42
# 3         3.61       3.86          4       3.82        3.94        3.83  3.72
# 4         3.37       3.32        3.1       3.15        3.37        3.84  3.26
# ..         ...        ...        ...        ...         ...         ...   ...
# 292       3.33       3.24        2.9       3.89         NaN         NaN  3.00
# 293       3.75       3.95       3.73          4         NaN         NaN  3.59
# 294       3.37       3.48       3.46       3.55        3.14        3.64  3.29
# 295        NaN        3.5       3.39       3.39        3.18        3.45  3.42
# 296        NaN       3.58       3.53       3.37         3.3        3.77  3.48
#
#      Penghasilan Orang Tua  Tanggungan Orang Tua  Tahun Masuk  Usia
# 0                      NaN                   NaN          NaN   NaN
# 1                1837300.0                   3.0       2017.0  18.0
# 2                2500000.0                   1.0       2017.0  19.0
# 3                1250000.0                   4.0       2017.0  20.0
# 4                1000000.0                   5.0       2017.0  20.0
# ..                     ...                   ...          ...   ...
# 292              5482100.0                   4.0       2016.0  19.0
# 293              5384634.0                   3.0       2016.0  19.0
# 294              2500000.0                   4.0       2017.0  20.0
# 295               300000.0                   2.0       2018.0  20.0
# 296              1000000.0                   4.0       2018.0  18.0
#
# [297 rows x 17 columns]

# %%
#Menghapus baris pertama 
df=df.drop([0])

#mengganti nama record
df=df.rename(columns={
    'NR':'NR1',
    'Unnamed: 2':'NR2',
    'Unnamed: 3':'NR3',
    'Unnamed: 4':'NR4',
    'Unnamed: 5':'NR5',
    'Unnamed: 6':'NR6',
    'Unnamed: 7':'NR7',
    'Unnamed: 8':'NR8',
    'Unnamed: 9':'NR9',
    'Unnamed: 10':'NR10',
    'Unnamed: 11':'NR11'
},inplace=False)
header=list(df)

#Menggeser value column
for i in df.index:
    j=1
    while math.isnan(float(df.loc[i, header[j]])):
        temp=df.loc[i, header[j]]
        for k in range(0,11):
            a=j+k
            b=a+1
            df.loc[i, header[a]]=df.loc[i, header[b]]
        df.loc[i, header[11]]=temp
df=df.reset_index(drop=True)
df
# Out:
#     Status Beasiswa BI   NR1   NR2   NR3   NR4   NR5   NR6   NR7  NR8  NR9  \
# 0                  Iya  3.19  3.45  2.93  2.95  2.62  3.13  3.37  NaN  NaN
# 1                  Iya  3.31  3.45  3.46  2.95   3.4  3.42   3.5  NaN  NaN
# 2                  Iya  3.83  3.61  3.86     4  3.82  3.94  3.83  NaN  NaN
# 3                  Iya  3.06  3.37  3.32   3.1  3.15  3.37  3.84  NaN  NaN
# 4                  Iya  3.59  3.24  3.12  3.16  3.61   3.5  3.74  NaN  NaN
# ..                 ...   ...   ...   ...   ...   ...   ...   ...  ...  ...
# 291              Tidak  2.95  2.65  3.03  3.33  3.24   2.9  3.89  NaN  NaN
# 292              Tidak  3.34  3.21  3.95  3.75  3.95  3.73     4  NaN  NaN
# 293              Tidak  2.97  3.37  3.48  3.46  3.55  3.14  3.64  NaN  NaN
# 294              Tidak   3.5  3.39  3.39  3.18  3.45   NaN   NaN  NaN  NaN
# 295              Tidak  3.58  3.53  3.37   3.3  3.77   NaN   NaN  NaN  NaN
#
#     NR10 NR11    IP  Penghasilan Orang Tua  Tanggungan Orang Tua  Tahun Masuk  \
# 0    NaN  NaN  3.35              1837300.0                   3.0       2017.0
# 1    NaN  NaN  3.42              2500000.0                   1.0       2017.0
# 2    NaN  NaN  3.72              1250000.0                   4.0       2017.0
# 3    NaN  NaN  3.26              1000000.0                   5.0       2017.0
# 4    NaN  NaN  3.40              1500000.0                   2.0       2017.0
# ..   ...  ...   ...                    ...                   ...          ...
# 291  NaN  NaN  3.00              5482100.0                   4.0       2016.0
# 292  NaN  NaN  3.59              5384634.0                   3.0       2016.0
# 293  NaN  NaN  3.29              2500000.0                   4.0       2017.0
# 294  NaN  NaN  3.42               300000.0                   2.0       2018.0
# 295  NaN  NaN  3.48              1000000.0                   4.0       2018.0
#
#      Usia
# 0    18.0
# 1    19.0
# 2    20.0
# 3    20.0
# 4    18.0
# ..    ...
# 291  19.0
# 292  19.0
# 293  20.0
# 294  20.0
# 295  18.0
#
# [296 rows x 17 columns]

# %%
#menghapus column
# df.info()
for i in range(8,12):
    if df[header[i]].isnull().sum():
        del df[header[i]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 13 columns):
# Status Beasiswa BI       296 non-null object
# NR1                      296 non-null object
# NR2                      296 non-null object
# NR3                      296 non-null object
# NR4                      296 non-null object
# NR5                      296 non-null object
# NR6                      225 non-null object
# NR7                      225 non-null object
# IP                       296 non-null float64
# Penghasilan Orang Tua    296 non-null float64
# Tanggungan Orang Tua     296 non-null float64
# Tahun Masuk              296 non-null float64
# Usia                     296 non-null float64
# dtypes: float64(5), object(8)
# memory usage: 30.2+ KB

# %%
#Mengisi data yang kosong
x=df.loc[:,header[0]]
df['Decision']=x
del df['Status Beasiswa BI']
# del df['NR1']
# del df['NR2']
# del df['NR3']
# del df['NR4']
# del df['NR5']
del df['NR6']
del df['NR7']
df=df.reset_index(drop=True)
df=df.to_numeric()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Status Beasiswa BI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-946ffefac0c3> in <module>
#       1 #Mengisi data yang kosong
# ----> 2 x=df.loc[:,header[0]]
#       3 df['Decision']=x
#       4 del df['Status Beasiswa BI']
#       5 # del df['NR1']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     803     def _getitem_tuple(self, tup):
#     804         try:
# --> 805             return self._getitem_lowerdim(tup)
#     806         except IndexingError:
#     807             pass
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     927         for i, key in enumerate(tup):
#     928             if is_label_like(key) or isinstance(key, tuple):
# --> 929                 section = self._getitem_axis(key, axis=i)
#     930
#     931                 # we have yielded a scalar ?
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3727
#    3728         if axis == 1:
# -> 3729             return self[key]
#    3730
#    3731         self._consolidate_inplace()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Status Beasiswa BI'

# %% [markdown]
# ## Splitting Data

# %%
import numpy as np
from sklearn.model_selection import train_test_split
##80 train, 20 test
df_train, df_test=np.split(df.sample(frac=1,random_state=42),[int(0.8*len(df))])

##80 train,10 validate,10 test
# df_train, df_validate, df_test = np.split(df.sample(frac=1,random_state=42),[int(.8*len(df)),int(.9*len(df))])

# %%
df_test
# Out:
#       NR1   NR2   NR3   NR4   NR5    IP  Penghasilan Orang Tua  \
# 220  3.58  3.59  3.91  3.78  3.93  3.71              1200000.0
# 240  3.12  2.89   2.9  3.19   2.9  3.00              2600000.0
# 3    3.06  3.37  3.32   3.1  3.15  3.26              1000000.0
# 105  3.47  3.82  3.86  3.78     4  3.72              1200000.0
# 53   3.71  3.53   3.7  3.89  3.87  3.65              1500000.0
# 133  3.71  3.34   3.8  3.58  3.69  3.62              2000000.0
# 1    3.31  3.45  3.46  2.95   3.4  3.42              2500000.0
# 131  3.61  3.61  3.75   3.9  3.82  3.66              1200000.0
# 103  3.71  3.11  3.43  3.63   3.9  3.41              2000000.0
# 49   3.94  3.89     4  3.95  3.96  3.95              2000000.0
# 163  3.63  3.45  3.31  3.13     3  3.45              3500000.0
# 80   3.59  3.24  3.12  3.16  3.61  3.30              1500000.0
# 205  2.82  2.85  2.98  3.02   3.4  3.13              3126200.0
# 34   3.29  3.47   3.7  3.33  3.26  3.46              1200000.0
# 268  3.29  3.63  3.58  3.37  3.82  3.51              2200000.0
# 7    3.33  3.67  3.62  3.14  3.28  3.54              2000000.0
# 171  2.87  2.53  3.05  2.95  3.55  3.02              1300000.0
# 198  3.82  3.37   0.1     0     0  3.58               525000.0
# 271  3.28  3.56  3.72   3.5  3.76  3.53              2580200.0
# 110  3.09  3.03     3  3.14  3.58  3.04               700000.0
# 91   3.06  3.28  3.64  3.21  3.46  3.34               500000.0
# 52      4  3.44  3.59  3.36  3.35  3.67              1200000.0
# 241  3.59     3  2.55  1.53  2.05  3.07              2000000.0
# 13   3.82  3.21  3.63  3.31  3.53  3.49              1500000.0
# 88   3.55  3.38  3.45  3.37  3.91  3.46               700000.0
# 166  3.47  2.89   3.1  3.05  2.65  3.14              1955654.0
# 290  3.33  3.36  3.79  3.66  3.52  3.51              1500000.0
# 134  3.44  3.61  3.94  3.68  3.69  3.71               900000.0
# 283  3.18  3.21  3.88  3.88     4  3.45              1000000.0
# 243  3.53  3.53   3.5  3.55  3.71  3.58                    0.0
# 54   3.84  3.94   3.9  3.45  3.88  3.89              2500000.0
# 50   3.68  3.65   3.8  3.65  3.61  3.71              1000000.0
# 174  2.97  3.53  3.35  3.08  3.45  3.28              4991300.0
# 189  3.26  3.16  3.48  2.98  2.58  3.21              1500000.0
# 294   3.5  3.39  3.39  3.18  3.45  3.42               300000.0
# 187  3.89     4   3.8  3.15  3.94  3.89              1000000.0
# 169  3.65  3.47  3.57  2.88  3.05  3.56              2000000.0
# 58   3.89  3.72  3.87  3.84  3.33  3.81               750000.0
# 48   3.19  2.95  2.85  3.16  3.65  3.03              1500000.0
# 235  3.42  3.15  3.07  3.61  3.36  3.36              7914100.0
# 252  3.28  3.39  3.33  3.02  3.34  3.33              1000000.0
# 21   2.94  3.29  3.26  2.87  2.88  3.13              2000000.0
# 160     3  3.05   3.2  2.57  3.29  3.09              2000000.0
# 276  3.94   3.5  3.75   3.5  3.87  3.72              1500000.0
# 191  2.97  2.53  3.24  3.21  2.83  3.01              4836800.0
# 257  3.39  3.12  3.27  3.18  3.43  3.25              9987472.0
# 149  2.84  2.38  3.08  3.56  3.35  3.02              4714500.0
# 130  3.67  3.83   3.8  3.67  3.72  3.77              1000000.0
# 151     3  2.47  3.47  3.48  3.29  3.19              2000000.0
# 99   3.74     3  3.88  3.25  3.71  3.51              2100000.0
# 87   3.71  3.63  3.32  3.94     4  3.72               900000.0
# 214  3.11     3  3.59  3.78  3.86  3.06              1500000.0
# 121  3.42  3.08  3.65  2.93  3.35  3.39               600000.0
# 295  3.58  3.53  3.37   3.3  3.77  3.48              1000000.0
# 20   3.59     3  2.55  1.53  2.05  3.28              1000000.0
# 188  2.58  2.38  3.63  3.52   3.7  3.18              3500000.0
# 71   3.53  3.47  3.52   3.5   3.6  3.50              2076900.0
# 106  3.16  3.29  3.83  3.64  3.79  3.46              2000000.0
# 270  3.47  2.62  3.35  2.89  3.29  3.11              3600000.0
# 102  3.32  3.82   3.8  3.89  3.68  3.65              1760000.0
#
#      Tanggungan Orang Tua  Tahun Masuk  Usia Decision
# 220                   5.0       2018.0  19.0    Tidak
# 240                   3.0       2017.0  19.0    Tidak
# 3                     5.0       2017.0  20.0      Iya
# 105                   4.0       2018.0  20.0      Iya
# 53                    4.0       2017.0  20.0      Iya
# 133                   5.0       2017.0  20.0      Iya
# 1                     1.0       2017.0  19.0      Iya
# 131                   3.0       2017.0  20.0      Iya
# 103                   4.0       2017.0  19.0      Iya
# 49                    5.0       2017.0  21.0      Iya
# 163                   3.0       2017.0  19.0    Tidak
# 80                    2.0       2017.0  19.0      Iya
# 205                   4.0       2015.0  21.0    Tidak
# 34                    5.0       2016.0  20.0      Iya
# 268                   1.0       2017.0  19.0    Tidak
# 7                     4.0       2018.0  22.0      Iya
# 171                   2.0       2016.0  20.0    Tidak
# 198                   3.0       2017.0  18.0    Tidak
# 271                   2.0       2018.0  20.0    Tidak
# 110                   1.0       2017.0  20.0      Iya
# 91                    3.0       2018.0  20.0      Iya
# 52                    4.0       2018.0  19.0      Iya
# 241                   2.0       2017.0  19.0    Tidak
# 13                    6.0       2017.0  20.0      Iya
# 88                    3.0       2018.0  19.0      Iya
# 166                   6.0       2017.0  19.0    Tidak
# 290                   3.0       2018.0  19.0    Tidak
# 134                   5.0       2018.0  19.0      Iya
# 283                   4.0       2018.0  19.0    Tidak
# 243                   2.0       2017.0  22.0    Tidak
# 54                    3.0       2018.0  20.0      Iya
# 50                    6.0       2018.0  19.0      Iya
# 174                   2.0       2016.0  20.0    Tidak
# 189                   2.0       2017.0  18.0    Tidak
# 294                   2.0       2018.0  20.0    Tidak
# 187                   4.0       2018.0  20.0    Tidak
# 169                   3.0       2017.0  19.0    Tidak
# 58                    4.0       2017.0  20.0      Iya
# 48                    1.0       2017.0  18.0      Iya
# 235                   4.0       2015.0  20.0    Tidak
# 252                   2.0       2018.0  18.0    Tidak
# 21                    2.0       2017.0  18.0      Iya
# 160                   3.0       2017.0  19.0    Tidak
# 276                   2.0       2017.0  20.0    Tidak
# 191                   1.0       2016.0  20.0    Tidak
# 257                   2.0       2016.0  19.0    Tidak
# 149                   3.0       2016.0  19.0    Tidak
# 130                   3.0       2018.0  20.0      Iya
# 151                   3.0       2016.0  21.0    Tidak
# 99                    3.0       2016.0  19.0      Iya
# 87                    5.0       2017.0  21.0      Iya
# 214                   3.0       2017.0  19.0    Tidak
# 121                   8.0       2018.0  21.0      Iya
# 295                   4.0       2018.0  18.0    Tidak
# 20                    1.0       2017.0  18.0      Iya
# 188                   2.0       2016.0  19.0    Tidak
# 71                    4.0       2017.0  19.0      Iya
# 106                   4.0       2018.0  20.0      Iya
# 270                   2.0       2016.0  21.0    Tidak
# 102                   3.0       2018.0  19.0      Iya

# %%
from chefboost import Chefboost as chef
import pandas as pd

config = {'algorithm': 'C4.5'}
model = chef.fit(df_train, config = config)
# Out:
# C4.5  tree is going to be built...
# -------------------------
# finished in  34.84932279586792  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  89.40677966101696 % on  236  instances
# Labels:  ['Tidak' 'Iya']
# Confusion matrix:  [[100, 7], [18, 111]]
# Precision:  93.4579 %, Recall:  84.7458 %, F1:  88.8889 %

# %% [markdown]
# # Pemodelan

# %%
rules = "outputs/rules/rules.py"
df_feature_importance = chef.feature_importance(rules).set_index("feature")
df_feature_importance.plot(kind="barh", title="Feature Importance")
# Out:
# Decision rule:  outputs/rules/rules.py

# %% [markdown]
# # Pruning

# %%
#Tidak Dapat di Pruning karena tidak dalam bentuk tree

# %% [markdown]
# # Testing

# %%
## CEK KETEPATAN DALAM KLASIFIKASI
decision_predict=[]
TP=0
TN=0
FP=0
FN=0

for index,instance in df_test.iterrows():
#     print(instance)
    prediction = chef.predict(model, instance)
#     print(index,instance['Decision'],prediction)
#     decision_predict.append(prediction)
    if instance['Decision'] != prediction:
        if (instance['Decision'] == "Iya") and (prediction !="Iya"):
            FN+=1
        else:
            FP+=1
    else:
        if (instance['Decision'] == "Iya") and (prediction =="Iya"):
            TP+=1
        else:
            TN+=1
    print(index," ",instance['Decision'],prediction,"| TP=",TP,", TN=",TN,", FP=",FP, ", FN=",FN)
        
# df_test['Decision Predict']=decision_predict
# Out:
# 220   Tidak Tidak | TP= 0 , TN= 1 , FP= 0 , FN= 0
# 240   Tidak Tidak | TP= 0 , TN= 2 , FP= 0 , FN= 0
# 3   Iya Iya | TP= 1 , TN= 2 , FP= 0 , FN= 0
# 105   Iya Tidak | TP= 1 , TN= 2 , FP= 0 , FN= 1
# 53   Iya Iya | TP= 2 , TN= 2 , FP= 0 , FN= 1
# 133   Iya Tidak | TP= 2 , TN= 2 , FP= 0 , FN= 2
# 1   Iya Iya | TP= 3 , TN= 2 , FP= 0 , FN= 2
# 131   Iya Tidak | TP= 3 , TN= 2 , FP= 0 , FN= 3
# 103   Iya Tidak | TP= 3 , TN= 2 , FP= 0 , FN= 4
# 49   Iya Iya | TP= 4 , TN= 2 , FP= 0 , FN= 4
# 163   Tidak Tidak | TP= 4 , TN= 3 , FP= 0 , FN= 4
# 80   Iya Iya | TP= 5 , TN= 3 , FP= 0 , FN= 4
# 205   Tidak Tidak | TP= 5 , TN= 4 , FP= 0 , FN= 4
# 34   Iya Iya | TP= 6 , TN= 4 , FP= 0 , FN= 4
# 268   Tidak Tidak | TP= 6 , TN= 5 , FP= 0 , FN= 4
# 7   Iya Iya | TP= 7 , TN= 5 , FP= 0 , FN= 4
# 171   Tidak Tidak | TP= 7 , TN= 6 , FP= 0 , FN= 4
# 198   Tidak Tidak | TP= 7 , TN= 7 , FP= 0 , FN= 4
# 271   Tidak Tidak | TP= 7 , TN= 8 , FP= 0 , FN= 4
# 110   Iya Tidak | TP= 7 , TN= 8 , FP= 0 , FN= 5
# 91   Iya Iya | TP= 8 , TN= 8 , FP= 0 , FN= 5
# 52   Iya Tidak | TP= 8 , TN= 8 , FP= 0 , FN= 6
# 241   Tidak Tidak | TP= 8 , TN= 9 , FP= 0 , FN= 6
# 13   Iya Iya | TP= 9 , TN= 9 , FP= 0 , FN= 6
# 88   Iya Iya | TP= 10 , TN= 9 , FP= 0 , FN= 6
# 166   Tidak Iya | TP= 10 , TN= 9 , FP= 1 , FN= 6
# 290   Tidak Tidak | TP= 10 , TN= 10 , FP= 1 , FN= 6
# 134   Iya Tidak | TP= 10 , TN= 10 , FP= 1 , FN= 7
# 283   Tidak Tidak | TP= 10 , TN= 11 , FP= 1 , FN= 7
# 243   Tidak Iya | TP= 10 , TN= 11 , FP= 2 , FN= 7
# 54   Iya Iya | TP= 11 , TN= 11 , FP= 2 , FN= 7
# 50   Iya Iya | TP= 12 , TN= 11 , FP= 2 , FN= 7
# 174   Tidak Tidak | TP= 12 , TN= 12 , FP= 2 , FN= 7
# 189   Tidak Tidak | TP= 12 , TN= 13 , FP= 2 , FN= 7
# 294   Tidak Tidak | TP= 12 , TN= 14 , FP= 2 , FN= 7
# 187   Tidak Iya | TP= 12 , TN= 14 , FP= 3 , FN= 7
# 169   Tidak Iya | TP= 12 , TN= 14 , FP= 4 , FN= 7
# 58   Iya Tidak | TP= 12 , TN= 14 , FP= 4 , FN= 8
# 48   Iya Tidak | TP= 12 , TN= 14 , FP= 4 , FN= 9
# 235   Tidak Tidak | TP= 12 , TN= 15 , FP= 4 , FN= 9
# 252   Tidak Tidak | TP= 12 , TN= 16 , FP= 4 , FN= 9
# 21   Iya Iya | TP= 13 , TN= 16 , FP= 4 , FN= 9
# 160   Tidak Iya | TP= 13 , TN= 16 , FP= 5 , FN= 9
# 276   Tidak Iya | TP= 13 , TN= 16 , FP= 6 , FN= 9
# 191   Tidak Tidak | TP= 13 , TN= 17 , FP= 6 , FN= 9
# 257   Tidak Tidak | TP= 13 , TN= 18 , FP= 6 , FN= 9
# 149   Tidak Tidak | TP= 13 , TN= 19 , FP= 6 , FN= 9
# 130   Iya Tidak | TP= 13 , TN= 19 , FP= 6 , FN= 10
# 151   Tidak Iya | TP= 13 , TN= 19 , FP= 7 , FN= 10
# 99   Iya Tidak | TP= 13 , TN= 19 , FP= 7 , FN= 11
# 87   Iya Tidak | TP= 13 , TN= 19 , FP= 7 , FN= 12
# 214   Tidak Tidak | TP= 13 , TN= 20 , FP= 7 , FN= 12
# 121   Iya Iya | TP= 14 , TN= 20 , FP= 7 , FN= 12
# 295   Tidak Iya | TP= 14 , TN= 20 , FP= 8 , FN= 12
# 20   Iya Tidak | TP= 14 , TN= 20 , FP= 8 , FN= 13
# 188   Tidak Iya | TP= 14 , TN= 20 , FP= 9 , FN= 13
# 71   Iya Iya | TP= 15 , TN= 20 , FP= 9 , FN= 13
# 106   Iya Tidak | TP= 15 , TN= 20 , FP= 9 , FN= 14
# 270   Tidak Iya | TP= 15 , TN= 20 , FP= 10 , FN= 14
# 102   Iya Iya | TP= 16 , TN= 20 , FP= 10 , FN= 14

# %%
##NR 1 sampai 7 dihapus
print(TP,TN,df_test.shape[0])
CTestAccuracy=(TP+TN)/df_test.shape[0]
print('C4.5 Testing accuracy: ',CTestAccuracy)
# df=df.reset_index(drop=True)
# print(df.iloc[295:,:12].values[0])
# Out:
# 16 20 60
# C4.5 Testing accuracy:  0.6

# %%
df_test.shape[0]
# Out:
# 60
